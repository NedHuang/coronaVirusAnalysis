# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics


#reading data from the csv file
data1 = pd.read_csv("COVID19_line_list_data.csv")
data2 = pd.read_csv("time_series_covid_19_confirmed.csv")

# %%
data2.head
# Out:
# <bound method NDFrame.head of     Province/State    Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0              NaN          Thailand  15.0000  101.0000        2        3
# 1              NaN             Japan  36.0000  138.0000        2        1
# 2              NaN         Singapore   1.2833  103.8333        0        1
# 3              NaN             Nepal  28.1667   84.2500        0        0
# 4              NaN          Malaysia   2.5000  112.5000        0        0
# ..             ...               ...      ...       ...      ...      ...
# 472   Sint Maarten       Netherlands  18.0425  -63.0548        0        0
# 473            NaN             Niger  17.6078    8.0817        0        0
# 474            NaN  Papua New Guinea  -6.3150  143.9555        0        0
# 475    Isle of Man    United Kingdom  54.2361   -4.5481        0        0
# 476            NaN          Zimbabwe -20.0000   30.0000        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/11/20  3/12/20  3/13/20  \
# 0          5        7        8        8  ...       59       70       75
# 1          2        2        4        4  ...      639      639      701
# 2          3        3        4        5  ...      178      178      200
# 3          0        1        1        1  ...        1        1        1
# 4          0        3        4        4  ...      149      149      197
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 472        0        0        0        0  ...        0        0        0
# 473        0        0        0        0  ...        0        0        0
# 474        0        0        0        0  ...        0        0        0
# 475        0        0        0        0  ...        0        0        0
# 476        0        0        0        0  ...        0        0        0
#
#      3/14/20  3/15/20  3/16/20  3/17/20  3/18/20  3/19/20  3/20/20
# 0         82      114      147      177      212      272      322
# 1        773      839      825      878      889      924      963
# 2        212      226      243      266      313      345      385
# 3          1        1        1        1        1        1        1
# 4        238      428      566      673      790      900     1030
# ..       ...      ...      ...      ...      ...      ...      ...
# 472        0        0        0        0        0        0        1
# 473        0        0        0        0        0        0        1
# 474        0        0        0        0        0        0        1
# 475        0        0        0        0        0        0        1
# 476        0        0        0        0        0        0        1
#
# [477 rows x 63 columns]>

# %%
data2.loc[data2['Country/Region'] == 'China']
# Out:
#      Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 154           Hubei          China  30.9756  112.2707      444      444
# 158       Guangdong          China  23.3417  113.4244       26       32
# 159           Henan          China  33.8820  113.6140        5        5
# 160        Zhejiang          China  29.1832  120.0934       10       27
# 161           Hunan          China  27.6104  111.7088        4        9
# 162           Anhui          China  31.8257  117.2264        1        9
# 163         Jiangxi          China  27.6140  115.7221        2        7
# 164        Shandong          China  36.3427  118.1498        2        6
# 166         Jiangsu          China  32.9711  119.4550        1        5
# 167       Chongqing          China  30.0572  107.8740        6        9
# 168         Sichuan          China  30.6171  102.7103        5        8
# 169    Heilongjiang          China  47.8620  127.7615        0        2
# 171         Beijing          China  40.1824  116.4142       14       22
# 172        Shanghai          China  31.2020  121.4491        9       16
# 173           Hebei          China  39.5490  116.1306        1        1
# 174          Fujian          China  26.0789  117.9874        1        5
# 175         Guangxi          China  23.8298  108.7881        2        5
# 176         Shaanxi          China  35.1917  108.8701        0        3
# 177          Yunnan          China  24.9740  101.4870        1        2
# 178          Hainan          China  19.1959  109.7453        4        5
# 179         Guizhou          China  26.8154  106.8748        1        3
# 180         Tianjin          China  39.3054  117.3230        4        4
# 181          Shanxi          China  37.5777  112.2922        1        1
# 182           Gansu          China  37.8099  101.0583        0        2
# 183       Hong Kong          China  22.3000  114.2000        0        2
# 184        Liaoning          China  41.2956  122.6085        2        3
# 185           Jilin          China  43.6661  126.1923        0        1
# 187        Xinjiang          China  41.1129   85.2401        0        2
# 188  Inner Mongolia          China  44.0935  113.9448        0        0
# 189         Ningxia          China  37.2692  106.1655        1        1
# 193         Qinghai          China  35.7452   95.9956        0        0
# 194           Macau          China  22.1667  113.5500        1        2
# 202           Tibet          China  31.6927   88.0924        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/11/20  3/12/20  3/13/20  \
# 154      549      761     1058     1423  ...    67773    67781    67786
# 158       53       78      111      151  ...     1356     1356     1356
# 159        9       32       83      128  ...     1273     1273     1273
# 160       43       62      104      128  ...     1215     1215     1215
# 161       24       43       69      100  ...     1018     1018     1018
# 162       15       39       60       70  ...      990      990      990
# 163       18       18       36       72  ...      935      935      935
# 164       15       27       46       75  ...      760      760      760
# 166        9       18       33       47  ...      631      631      631
# 167       27       57       75      110  ...      576      576      576
# 168       15       28       44       69  ...      539      539      539
# 169        4        9       15       21  ...      482      482      482
# 171       36       41       68       80  ...      435      435      436
# 172       20       33       40       53  ...      344      344      346
# 173        2        8       13       18  ...      318      318      318
# 174       10       18       35       59  ...      296      296      296
# 175       23       23       36       46  ...      252      252      252
# 176        5       15       22       35  ...      245      245      245
# 177        5       11       16       26  ...      174      174      174
# 178        8       19       22       33  ...      168      168      168
# 179        3        4        5        7  ...      146      146      146
# 180        8       10       14       23  ...      136      136      136
# 181        1        6        9       13  ...      133      133      133
# 182        2        4        7       14  ...      127      127      127
# 183        2        5        8        8  ...      126      129      134
# 184        4       17       21       27  ...      125      125      125
# 185        3        4        4        6  ...       93       93       93
# 187        2        3        4        5  ...       76       76       76
# 188        1        7        7       11  ...       75       75       75
# 189        2        3        4        7  ...       75       75       75
# 193        0        1        1        6  ...       18       18       18
# 194        2        2        5        6  ...       10       10       10
# 202        0        0        0        0  ...        1        1        1
#
#      3/14/20  3/15/20  3/16/20  3/17/20  3/18/20  3/19/20  3/20/20
# 154    67790    67794    67798    67799    67800    67800    67800
# 158     1356     1360     1361     1364     1370     1378     1395
# 159     1273     1273     1273     1273     1273     1273     1273
# 160     1227     1231     1231     1232     1232     1233     1234
# 161     1018     1018     1018     1018     1018     1018     1018
# 162      990      990      990      990      990      990      990
# 163      935      935      935      935      935      935      935
# 164      760      760      760      761      761      761      762
# 166      631      631      631      631      631      631      631
# 167      576      576      576      576      576      576      576
# 168      539      539      539      540      540      540      541
# 169      482      482      482      482      482      483      484
# 171      437      442      452      456      469      480      491
# 172      353      353      355      358      361      363      371
# 173      318      318      318      318      318      318      318
# 174      296      296      296      296      296      296      299
# 175      252      252      252      253      253      253      254
# 176      245      245      245      246      246      246      247
# 177      174      174      176      176      176      176      176
# 178      168      168      168      168      168      168      168
# 179      146      146      146      147      146      146      146
# 180      136      136      136      136      136      137      137
# 181      133      133      133      133      133      133      133
# 182      129      133      133      133      133      134      134
# 183      140      145      155      162      181      208      256
# 184      125      125      125      125      125      125      126
# 185       93       93       93       93       93       93       93
# 187       76       76       76       76       76       76       76
# 188       75       75       75       75       75       75       75
# 189       75       75       75       75       75       75       75
# 193       18       18       18       18       18       18       18
# 194       10       10       11       12       15       17       17
# 202        1        1        1        1        1        1        1
#
# [33 rows x 63 columns]

# %%
chinaData=data2.loc[data2['Country/Region'] =='China']

# %%
chinaTotalByDate = chinaData.groupby(["Country/Region"]).sum()

# %%
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20',
#        '3/19/20', '3/20/20'],
#       dtype='object')

# %%
dateData = np.array(list(data2.columns[4:]))
data2.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
#        '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20'],
#       dtype='object')

# %%
chinaDailyCount = chinaTotalByDate[dateData].to_numpy().reshape(len(dataDate))
print(chinaDailyCount)
plt.plot(dateData, chinaDailyCount)
# Out:
# [  548   643   920  1406  2075  2877  5509  6087  8141  9802 11891 16630
#  19716 23707 27440 30587 34110 36814 39829 42354 44386 44759 59895 66358
#  68413 70513 72434 74211 74619 75077 75550 77001 77022 77241 77754 78166
#  78600 78928 79356 79932 80136 80261 80386 80537 80690 80770 80823 80860
#  80887 80921 80932 80945 80977 81003 81033 81058 81102 81156 81250]

# %%
chinaDailyCountSmoothed = [chinaDailyCount[0] for _ in range(6)] + chinaDailyCount + [chinaDailyCount[-1] for _ in range(6)]
print(chinaDailyCountSmoothed)
# chinaDailyCountSmoothed = [statistics.mean(chinaDailyCountSmoothed[i-7:i]) for i in range(6,len(chinaDailyCountSmoothed)-6)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-31758cfed410> in <module>
# ----> 1 chinaDailyCountSmoothed = [chinaDailyCount[0]]*6 + chinaDailyCount + [chinaDailyCount[-1]*6]
#       2 print(chinaDailyCountSmoothed)
#       3 # chinaDailyCountSmoothed = [statistics.mean(chinaDailyCountSmoothed[i-7:i]) for i in range(6,len(chinaDailyCountSmoothed)-6)]
#
# ValueError: operands could not be broadcast together with shapes (6,) (59,)

# %%
# Out:
# 2
